# %% [markdown]
# # Plasma Diagnostics

# %%
import numpy as np
import matplotlib.pyplot as plt
import astropy
import sys
import astropy.io.fits as fits

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %% [markdown]
# Choosing pixels for omparisong between observed spectra and 'best-match' model spectra:
# - **Single peaked spectra**: [13,55,190], [13,30,180]
# - **Centrally Reversed Spectra**: [13,15,170], [13,25,154]
# - **Complex Spectra**: [13,20,120], [13,5,115]

# %%
file_name = "spectroscopic_data/iris_l2_20140528_112458_3820111493_raster_t000_r00013.fits"

raster13 = fits.open(file_name, memmap=False, do_not_scale_image = False) # raster files are largers so memmap is a good idea
print(raster13[8].data.shape)

plt.figure(figsize=[20,10])
plt.imshow(raster13[8].data[..., 66], vmin=-200, vmax=800)
x1 = [190,180]
y1 = [55,30]
x2 = [156,154]
y2 = [34,25]
x3 = [141,140]
y3 = [61,46]
plt.plot(x1,y1,'x', color='r', label='single peaked')
plt.plot(x2,y2,'x', color='b', label='centrally reversed')
plt.plot(x3,y3,'x', color='y', label='complex')
plt.legend()
plt.grid()
plt.show()
# Out:
# (64, 548, 268)

# %%
import rrms_final
# Out:
# Loading older run.
# Run from 2022-02-16 09:41:01 on hercules.astro.gla.ac.uk
# Skip plotting? (y/n): n
# Creating filters/masks..
# Producing plots...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 16/16 [03:08<00:00, 11.76s/it]
# Percentage of good matches: 58.83%
# 116665 / 198320
# Would you like to look at some comparisons in detail? (y/n): n
